# %%
from bin.FDCA_classification_concat_median import *

# %%
RCA = FDCA('Haber-man',
            11, 2, comp_others=True)
RCA.fit()
# Out:
# 1    225
# 2     81
# Name: Class, dtype: int64
# 1    225
# 2    225
# Name: Class, dtype: int64
# *************************MultinomialNB************************************
#               precision    recall  f1-score   support
#
#            1       0.57      0.90      0.70        42
#            2       0.83      0.40      0.54        48
#
#     accuracy                           0.63        90
#    macro avg       0.70      0.65      0.62        90
# weighted avg       0.71      0.63      0.61        90
#
# Precision: 0.567
# Recall: 0.905
# Accuracy: 0.633
# F1 Score: 0.697
# **************************svm********************
#               precision    recall  f1-score   support
#
#            1       0.53      0.90      0.67        42
#            2       0.78      0.29      0.42        48
#
#     accuracy                           0.58        90
#    macro avg       0.65      0.60      0.55        90
# weighted avg       0.66      0.58      0.54        90
#
# ...

# %%
from bin.FDCA_classification_concat_median_balloon import *

# %%
RCA = FDCA('Balloons',
             9, 2, comp_others=True)
RCA.fit()
# Out:
# 2    9
# 1    7
# Name: Class, dtype: int64
# *************************MultinomialNB************************************
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            2       0.50      0.33      0.40         3
#
#     accuracy                           0.25         4
#    macro avg       0.25      0.17      0.20         4
# weighted avg       0.38      0.25      0.30         4
#
# Precision: 0.000
# Recall: 0.000
# Accuracy: 0.250
# F1 Score: 0.000
# **************************svm********************
#               precision    recall  f1-score   support
#
#            1       0.25      1.00      0.40         1
#            2       0.00      0.00      0.00         3
#
#     accuracy                           0.25         4
#    macro avg       0.12      0.50      0.20         4
# weighted avg       0.06      0.25      0.10         4
#
# Precision: 0.250
# Recall: 1.000
# Accuracy: 0.250
# ...

# %%
from bin.FDCA_classification_concat_median_GenderClassification import *

# %%
RCA = FDCA('Gender Classification-kaggle-edited',
             9, 2, comp_others=True)
RCA.fit()
# Out:
# 1    33
# 2    33
# Name: Class, dtype: int64
# *************************MultinomialNB************************************
#               precision    recall  f1-score   support
#
#            1       0.67      0.25      0.36         8
#            2       0.45      0.83      0.59         6
#
#     accuracy                           0.50        14
#    macro avg       0.56      0.54      0.48        14
# weighted avg       0.58      0.50      0.46        14
#
# Precision: 0.667
# Recall: 0.250
# Accuracy: 0.500
# F1 Score: 0.364
# **************************svm********************
#               precision    recall  f1-score   support
#
#            1       0.50      0.25      0.33         8
#            2       0.40      0.67      0.50         6
#
#     accuracy                           0.43        14
#    macro avg       0.45      0.46      0.42        14
# weighted avg       0.46      0.43      0.40        14
#
# Precision: 0.500
# Recall: 0.250
# Accuracy: 0.429
# ...

# %%
from bin.FDCA_classification_concat_median_insurance import *

# %%
RCA = FDCA('insurance_data_edited',
             9, 2, comp_others=True)
RCA.fit()
# Out:
# 1    14
# 0    13
# Name: Class, dtype: int64
# *************************MultinomialNB************************************
#               precision    recall  f1-score   support
#
#            0       0.17      1.00      0.29         1
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.17         6
#    macro avg       0.08      0.50      0.14         6
# weighted avg       0.03      0.17      0.05         6
#
# Precision: 0.000
# Recall: 0.000
# Accuracy: 0.167
# F1 Score: 0.000
# **************************svm********************
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         5
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
# Precision: 1.000
# Recall: 1.000
# Accuracy: 1.000
# ...

# %%
from bin.FDCA_classification_concat_median_monk2 import *

# %%
RCA = FDCA('monks-2-new-edited',
             9, 2, comp_others=True)
RCA.fit()
# Out:
# 0    290
# 1    142
# Name: Class, dtype: int64
# 0    290
# 1    290
# Name: Class, dtype: int64
# *************************MultinomialNB************************************
#               precision    recall  f1-score   support
#
#            0       0.56      0.37      0.44        60
#            1       0.51      0.70      0.59        56
#
#     accuracy                           0.53       116
#    macro avg       0.54      0.53      0.52       116
# weighted avg       0.54      0.53      0.51       116
#
# Precision: 0.506
# Recall: 0.696
# Accuracy: 0.526
# F1 Score: 0.586
# **************************svm********************
#               precision    recall  f1-score   support
#
#            0       0.74      0.42      0.53        60
#            1       0.57      0.84      0.68        56
#
#     accuracy                           0.62       116
#    macro avg       0.65      0.63      0.61       116
# weighted avg       0.66      0.62      0.60       116
#
# ...
